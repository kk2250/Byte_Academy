# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('cpuo.csv')

# %%
data
# Out:
#     Year  Ranking                     Precinct / Command  Complaints Count  \
# 0   2009        1                   Patrol Borough Bronx               772
# 1   2009        2          Patrol Borough Brooklyn North               603
# 2   2009        3          Patrol Borough Brooklyn South               440
# 3   2009        4         Organized Crime Control Bureau               294
# 4   2009        5            Patrol Borough Queens South               265
# 5   2009        6                         Housing Bureau               289
# 6   2009        7         Patrol Borough Manhattan North               430
# 7   2009        8           Patrol Borough Staten Island               136
# 8   2009        9         Patrol Borough Manhattan South               264
# 9   2009       10            Patrol Borough Queens North               182
# 10  2009       11               Traffic Control Division                57
# ...

# %%
df = data

# %%
df
# Out:
#     Year  Ranking                     Precinct / Command  Complaints Count  \
# 0   2009        1                   Patrol Borough Bronx               772
# 1   2009        2          Patrol Borough Brooklyn North               603
# 2   2009        3          Patrol Borough Brooklyn South               440
# 3   2009        4         Organized Crime Control Bureau               294
# 4   2009        5            Patrol Borough Queens South               265
# 5   2009        6                         Housing Bureau               289
# 6   2009        7         Patrol Borough Manhattan North               430
# 7   2009        8           Patrol Borough Staten Island               136
# 8   2009        9         Patrol Borough Manhattan South               264
# 9   2009       10            Patrol Borough Queens North               182
# 10  2009       11               Traffic Control Division                57
# ...

# %%
df.shape
# Out:
# (51, 5)

# %%
df['Complaints Count'].max()
# Out:
# 887

# %%
df.loc[df['Complaints Count'].idxmax()]
# Out:
# Year                                          2010
# Ranking                                          1
# Precinct / Command            Patrol Borough Bronx
# Complaints Count                               887
# Number Of Subject Officers                    3433
# Name: 17, dtype: object

# %%
df[df['Year'] == 2009]['Complaints Count'].mean()
# Out:
# 250.1764705882353

# %%
b = df[df['Year'] == 2010]['Complaints Count'].mean()
c = df[df['Year'] == 2011]['Complaints Count'].mean()
a = df[df['Year'] == 2009]['Complaints Count'].mean()

# %%
print(a)
print(b)
print(c)
# Out:
# 250.1764705882353
# 259.8235294117647
# 250.0

# %%
df1 = df[df['Year'] == 2009]['Complaints Count']

# %%
df2 = df[df['Year'] == 2010]['Complaints Count']

# %%
df3 = df[df['Year'] == 2011]['Complaints Count']

# %%
print(df1)
print(df2)
print(df3)
# Out:
# 0     772
# 1     603
# 2     440
# 3     294
# 4     265
# 5     289
# 6     430
# 7     136
# 8     264
# 9     182
# 10     57
# 11    198
# 12    212
# 13     16
# 14     66
# 15      3
# 16     26
# Name: Complaints Count, dtype: int64
# 17    887
# 18    616
# 19    477
# 20    328
# 21    331
# 22    301
# 23    412
# 24    140
# 25    243
# 26    162
# 27     61
# 28    177
# 29    184
# 30     18
# 31     56
# 32      3
# 33     21
# Name: Complaints Count, dtype: int64
# 34    797
# 35    612
# 36    351
# 37    318
# 38    410
# 39    392
# 40    120
# 41    285
# 42    243
# 43    211
# 44     60
# 45    175
# 46    160
# 47     21
# 48     45
# 49     50
# 50      0
# Name: Complaints Count, dtype: int64

# %%
df['Complaints Count'].sum()
# Out:
# 12920

# %%
df['Number Of Subject Officers'].sum()
# Out:
# 103433

# %%
df.loc[df['Complaints Count'].idxmin()]
# Out:
# Year                                                          2011
# Ranking                                                         17
# Precinct / Command            Deputy Commissioners and Misc. Units
# Complaints Count                                                 0
# Number Of Subject Officers                                     186
# Name: 50, dtype: object
