# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
import sys

# %%
print(sys.version)
# Out:
# 3.7.0 (default, Aug 22 2018, 15:22:56)
# [Clang 9.0.0 (clang-900.0.39.2)]

# %%
print(pd.__version__)
# Out:
# 0.23.4

# %%
print(matplotlib.__version__)
# Out:
# 2.2.3

# %%
print(pd.__version__)
# Out:
# 0.23.4

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

# %%
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
print(data)
print(labels)
# Out:
# {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'], 'age': [2.5, 3, 0.5, nan, 5, 2, 4.5, nan, 7, 3], 'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1], 'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
df = pd.DataFrame(data, index = labels)

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
# animal      10 non-null object
# age         8 non-null float64
# visits      10 non-null int64
# priority    10 non-null object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes
# None

# %%
df.iloc[0:3]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
df.iloc[:, 0:2]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %%
df.iloc[[2,3,7], 0:2]
# Out:
#   animal  age
# c  snake  0.5
# d    dog  NaN
# h    cat  NaN

# %%
df.loc[df['visits'] >= 3]
# Out:
#   animal  age  visits priority
# b    cat  3.0       3      yes
# d    dog  NaN       3      yes
# f    cat  2.0       3       no

# %%
df[df['age'].isnull()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
df[(df.age<3) & (df.animal == 'cat')]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %%
df[(df.age<=4)&(df.age>=2)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %%
df.set_value('f','age',1.5)
# Out:
# /usr/local/Cellar/ipython/6.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """Entry point for launching an IPython kernel.
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df['visits'].sum()
# Out:
# 19

# %%
a = df[df['animal']=='cat']['age'].mean()

b = df[df['animal']=='dog']['age'].mean()

c = df[df['animal']=='snake']['age'].mean()

# %%
print(a)
print(b)
print(c)
# Out:
# 2.3333333333333335
# 5.0
# 2.5

# %%
data1 = {'animal': ['snake'],
        'age': [2.5],
        'visits': [2],
        'priority': ['yes']}
label = ['k']

# %%
df1 = pd.DataFrame(data1, index = label)

# %%
print(df1)
# Out:
#   animal  age  visits priority
# k  snake  2.5       2      yes

# %%
df.append(df1)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no
# k  snake  2.5       2      yes

# %%
df[:-1]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df.set_index(['animal','priority']).count(level='animal')
# Out:
#         age  visits
# animal
# cat       3       4
# dog       3       4
# snake     2       2

# %%
df.groupby('animal').count()
# Out:
#         age  visits  priority
# animal
# cat       3       4         4
# dog       3       4         4
# snake     2       2         2

# %%
df['animal'].value_counts()
# Out:
# dog      4
# cat      4
# snake    2
# Name: animal, dtype: int64

# %%
df.sort_values(by=['age'])
# Out:
#   animal  age  visits priority
# c  snake  0.5       2       no
# f    cat  1.5       3       no
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# j    dog  3.0       1       no
# g  snake  4.5       1       no
# e    dog  5.0       2       no
# i    dog  7.0       2       no
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
df.sort_values(by=['visits'])
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# j    dog  3.0       1       no
# c  snake  0.5       2       no
# e    dog  5.0       2       no
# i    dog  7.0       2       no
# b    cat  3.0       3      yes
# d    dog  NaN       3      yes
# f    cat  1.5       3       no

# %%
df = df.replace(['yes'], 'Ture')

# %%
df = df.replace(['no'], 'False')

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1     Ture
# b    cat  3.0       3     Ture
# c  snake  0.5       2    False
# d    dog  NaN       3     Ture
# e    dog  5.0       2    False
# f    cat  1.5       3    False
# g  snake  4.5       1    False
# h    cat  NaN       1     Ture
# i    dog  7.0       2    False
# j    dog  3.0       1    False

# %%
df = df.replace(['snake'], 'python')

# %%
df
# Out:
#    animal  age  visits priority
# a     cat  2.5       1     Ture
# b     cat  3.0       3     Ture
# c  python  0.5       2    False
# d     dog  NaN       3     Ture
# e     dog  5.0       2    False
# f     cat  1.5       3    False
# g  python  4.5       1    False
# h     cat  NaN       1     Ture
# i     dog  7.0       2    False
# j     dog  3.0       1    False

# %%
animal_age_table = pd.pivot_table(df, index = 'animal', values = 'age')

# %%
animal_age_table
# Out:
#              age
# animal
# cat     2.333333
# dog     5.000000
# python  2.500000

# %%
df = pd.DataFrame({'A': [1, 2, 2, 3, 4, 5, 5, 5, 6, 7, 7]})

# %%
df
# Out:
#     A
# 0   1
# 1   2
# 2   2
# 3   3
# 4   4
# 5   5
# 6   5
# 7   5
# 8   6
# 9   7
# 10  7

# %%
df.iloc[:,]
# Out:
#     A
# 0   1
# 1   2
# 2   2
# 3   3
# 4   4
# 5   5
# 6   5
# 7   5
# 8   6
# 9   7
# 10  7

# %%
df = pd.DataFrame(np.random.random(size=(5, 3)))
